# %% [markdown]
# <a href="https://colab.research.google.com/github/Aarsh13/GenAI_Lab/blob/main/Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input,decode_predictions
import numpy as np

# %%
model=ResNet50(weights='imagenet')
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
img_path='/content/sample_data/object.jpg'
img=image.load_img(img_path,target_size=(224,224))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
x=preprocess_input(x)

# %%
preds = model.predict(x)
print("Raw predictions:", preds)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# Raw predictions: [[4.29802824e-08 1.01712305e-06 1.23322209e-07 2.81075945e-08
#   1.21786812e-07 1.84885869e-06 1.27051848e-07 1.54069369e-06
#   5.32808087e-07 4.83872384e-07 8.93970366e-07 1.55945258e-06
#   2.12305918e-06 5.49828201e-07 3.33898379e-06 2.48997890e-06
#   1.28117654e-06 1.82382735e-07 3.29173463e-06 6.33382740e-07
#   4.63303905e-07 4.10719565e-08 1.22742122e-07 4.04703997e-07
#   6.17498728e-08 9.04104169e-08 5.13253838e-07 1.50647395e-06
#   6.62322464e-07 2.69910998e-07 7.56775904e-08 6.52016183e-07
#   1.81184973e-07 6.64686484e-09 1.66858271e-07 2.25488428e-08
#   1.42300212e-06 7.27059671e-07 8.22033570e-08 1.91277678e-07
#   2.17396178e-06 5.28057846e-08 1.40506344e-07 2.51972629e-08
#   5.20125695e-07 8.99214854e-08 1.14116358e-06 5.42970504e-08
#   2.07142534e-08 1.57184683e-08 1.24913582e-08 6.52430458e-07
#   1.15408693e-06 3.26267326e-07 2.00268886e-07 6.69873543e-07
# ...

# %%
decoded = decode_predictions(preds, top=5)[0]

print("\nTop Predictions:\n")
for i, (imagenet_id, label, score) in enumerate(decoded):
    print(f"{i+1}. {label}: {score*100:.2f}%")
# Out:
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# Top Predictions:
#
# 1. Granny_Smith: 93.12%
# 2. strawberry: 2.16%
# 3. hip: 0.73%
# 4. orange: 0.53%
# 5. pomegranate: 0.36%
